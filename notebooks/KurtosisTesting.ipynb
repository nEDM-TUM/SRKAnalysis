# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import srkgraphics
import srkmisc
import srkdata
import srkanalysis
import math
import ROOT
from ROOT import TF1,gPad,gStyle,TCanvas,TH1D,gROOT
import rootnotes
import rootprint
gStyle.SetOptFit()
c1=rootnotes.canvas("Canvas", (1200, 800))
c1.SetRightMargin(0.3)
histogram = TH1D("phi_hist","phi_hist",100,-5,5)
histwnoise = TH1D("phi_hist","phi_histw_noise",100,-5,5)
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: phi_hist (Potential memory leak).

# %% [markdown]
# #** E Field = 0.5 MV/m **
#
# **Parallel Fields Skewnormal fit**

# %%
rid=4864
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus((x-[1])/[2],0,1)*(1+TMath::Erf([0]*(x-[1])/[2]))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x34e5b00>

# %% [markdown]
# **Anti-Parallel Fields Skewnormal fit**

# %%
rid=4842
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus((x-[1])/[2],0,1)*(1+TMath::Erf([0]*(x-[1])/[2]))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4831
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus((x-[1])/[2],0,1)*(1+TMath::Erf([0]*(x-[1])/[2]))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4844
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4864
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4875
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4876
par=False
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %% [markdown]
# **EField =0**

# %%
rid=399
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
dip_pos=-0.001
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("No E Field Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=400
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
dip_pos=-0.01
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("No E Field Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func.SetParNames("Skew Factor","Offset","Sigma","Amplitude")
func.SetParameters(1.5,-1.2,1.5,216)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("skewnormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=377
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
dip_pos=-0.01
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("No E Field Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
# func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
func = TF1("Gamma","[3]*TMath::GammaDist(x,[0],[1],[2])",-5,5)
func.SetParNames("Gamma","Mu","Beta","Amplitude")
func.SetParameters(1.5,-1,.3,57)
func.SetParLimits(0,-10,10)
func.SetParLimits(1,-3,3)
func.SetParLimits(2,0.5,2)
func.SetParLimits(3,htemp.Integral()*0.0001,htemp.Integral())
htemp.Fit("Gamma","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=377
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
dip_pos=-0.01
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("No E Field Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
# func = TF1("skewnormal","[3]*TMath::Gaus(x-[1],0,[2])*(1+TMath::Erf([0]*(x-[1])))",-5,5)
# func = TF1("Gamma","[3]*TMath::GammaDist(x,[0],[1],[2])",-5,5)
func = TF1("LogNormal","[3]*TMath::LogNormal(x,[0],[1],[2])",-5,5)
func.SetParNames("sigma","theta","m","Amplitude")
func.SetParameters(1,-.8,.6,67)
htemp.Fit("LogNormal","M")
func.Draw("same")
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=377
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
dip_pos=-0.01
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("No E Field Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
func = TF1("PowerLogNormal","[3]*TMath::Gaus(TMath::Log(x-[1])/[2])*TMath::Power(ROOT::Math::normal_cdf(-TMath::Log(x-[1])/[2]),[0]-1.)",-.7,5)
func.SetParNames("power","sigma","shift","amplitude")
func.SetParameters(1,-2,0.5,90)
htemp.Fit("PowerLogNormal","M")
func.Draw("same")
c1
# Out:
# Fit:0: RuntimeWarning: Abnormal termination of minimization.
# <ROOT.TCanvas object ("Canvas") at 0x38cb270>

# %%
rid=4822
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x-[3])/[1])*((x-[3])/[1]),[2])", -5)
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power", "Mean");
phiTsallisFunc.SetParameters(250, stdev * 0.005, .76, 0);
phiTsallisFunc.SetParLimits(3, 0, 0);
htemp.Fit("phiTsallisFunc","M")
phiTsallisFunc.Draw("same")
gaus = TF1("gaus","300*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
c1.SetLogy()
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x3198220>

# %%
rid=201
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x-[3])/[1])*((x-[3])/[1]),[2])", -5)
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power", "Mean")
phiTsallisFunc.SetParameters(250, stdev * 0.005, .76, 0)
phiTsallisFunc.SetParLimits(3, 0, 0)
htemp.Fit("phiTsallisFunc","M")
phiTsallisFunc.Draw("same")
gaus = TF1("gaus","300*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
c1.SetLogy()
c1
# Out:
# <ROOT.TCanvas object ("Canvas") at 0x34e5b00>

# %%
reload(srkanalysis)
rid=575
par=True
noise_func=TF1("noise_func",srkmisc.gauss_noise_func,-10,10,1)
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
drawString="(phi-"+str(mean)+")/"+str(stdev)
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString,"abs("+drawString+") < 5")
htemp = gPad.GetPrimitive("htemp")
htemp.GetXaxis().SetRangeUser(-5.,5.)
htemp.SetTitle("Normalized Phi - "+par_str+"Fields with Dipole "+str(dip_str)+" T m^{3},  "+str(-dip_pos*100.)+" cm Below Chamber;Normalized Phi;Counts")
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x-[3])/[1])*((x-[3])/[1]),[2])", -5)
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power", "Mean");
phiTsallisFunc.SetParameters(400, stdev*2 , 21, 0);
phiTsallisFunc.SetParLimits(3, 0, 0);

gaus = TF1("gaus","25000*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")

hist_wnoise = srkanalysis.make_phi_hist_with_noise(rid, par, srkmisc.get_hist_dim(htemp), 1*stdev,True)
hist_wnoise.SetLineColor(ROOT.kViolet)
hist_wnoise.Draw("same")

hist_wnoise.Fit("phiTsallisFunc","M")
phiTsallisFunc.Draw("same")


c1.SetLogy()
c1
#
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: blurredHist575 (Potential memory leak).
# <ROOT.TCanvas object ("Canvas") at 0x34e5b00>

# %%
c1.Clear()
rid=6185
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
histogram.IsA().Destructor( histogram )
histogram = TH1D("phi_hist","phi_hist",100,-5,5)

drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle("Low Electric Field Gradient;Normalized Phi;Counts")
histogram.Draw()
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x)/[1])*((x)/[1]),[2])", -5)
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power");
phiTsallisFunc.SetParLimits(1,0.5,8)
phiTsallisFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
phiTsallisFunc.SetParLimits(2,0,100)
phiTsallisFunc.SetParameters(max_bin, stdev,2)
histogram.Fit("phiTsallisFunc","M")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
# phiTsallisFunc.Draw("same")
gaus = TF1("gaus","8000*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
c1.SetLogy()
c1
# Out:
# OK
# <ROOT.TCanvas object ("Canvas") at 0x3281400>

# %%
c1.Clear()
rid=6196
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
histogram.IsA().Destructor( histogram )
histogram = TH1D("phi_hist","phi_hist",100,-5,5)

drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle("Strong Electric Field Gradient;Normalized Phi;Counts")
histogram.Draw()
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x)/[1])*((x)/[1]),[2])", -5)
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power");
phiTsallisFunc.SetParLimits(1,0.5,8)
phiTsallisFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
phiTsallisFunc.SetParLimits(2,0,100)
phiTsallisFunc.SetParameters(max_bin, stdev,2)
histogram.Fit("phiTsallisFunc","M")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
# phiTsallisFunc.Draw("same")
gaus = TF1("gaus","4000*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
c1.SetLogy()
c1
# Out:
# OK
# <ROOT.TCanvas object ("Canvas") at 0x3281400>

# %%
c1.Clear()
rid=7329
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
print mean, stdev
histogram.IsA().Destructor( histogram )
histogram = TH1D("phi_hist","phi_hist",100,-5,5)

drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle(";Normalized Phi;Counts")
histogram.Draw()
phiTsallisFunc = TF1("phiTsallisFunc", "[0]/pow(1+((x)/[1])*((x)/[1]),[2])", -5)
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
phiTsallisFunc.SetParNames("Amplitude", "Sigma", "Power");
phiTsallisFunc.SetParLimits(1,0.1,20)
phiTsallisFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
phiTsallisFunc.SetParLimits(2,0,100)
phiTsallisFunc.SetParameters(max_bin, stdev,2)
histogram.Fit("phiTsallisFunc","M")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
# phiTsallisFunc.Draw("same")
gaus = TF1("gaus","400*TMath::Gaus(x,0,1)",-5,5)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
c1.SetLogy()
c1
# Out:
# 4845.7883801 3.90710433132e-06
# OK
# <ROOT.TCanvas object ("Canvas") at 0x1d78600>

# %%
c1.Clear()
rid=7543
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
print mean, stdev
histogram.IsA().Destructor( histogram )
range_val=5
histogram = TH1D("phi_hist","phi_hist",100,-range_val,range_val)



drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle(";Normalized Phi;Counts")
histogram.Draw()
qGaussianFunc = TF1("qGaussianFunc", "[0]*pow(1+([2]-1)*[1]*x*x,-1/([2]-1))")
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
print max_bin
print histogram.GetKurtosis()/range_val
qGaussianFunc.SetParLimits(1,0.1,20)
qGaussianFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
qGaussianFunc.SetParLimits(2,1.0001,3)
qGaussianFunc.SetParameters(max_bin, 3,2)
qGaussianFunc.Print()
histogram.Fit("qGaussianFunc","MV")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
print qGaussianFunc.GetChisquare() / qGaussianFunc.GetNDF()
# qGaussianFunc.Draw("same")
gaus = TF1("gaus","7000*TMath::Gaus(x,0,1)",-range_val,range_val)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
# histwnoise.IsA().Destructor( histwnoise )
# histwnoise=srkanalysis.make_phi_hist_with_noise(rid, par, srkmisc.get_hist_dim(histogram), 2*stdev,True)
# histwnoise.SetLineColor(ROOT.kCyan)
# histwnoise.Draw("same")
c1.SetLogy()
c1
# Out:
# None None
# /media/mjbales/data/nedm/results/Results_RID7543_P.root doesn't exist or is zombie.
# 0.0
# nan
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: phi_hist (Potential memory leak).
# Fit:0: RuntimeWarning: Fit data is empty
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8c153b0ae018> in <module>()
#      25 qGaussianFunc.Print()
#      26 histogram.Fit("qGaussianFunc","MV")
# ---> 27 if ROOT.gMinuit.fCstatu == "CONVERGED ":
#      28     print "YAY!!!"
#      29 print ROOT.gMinuit.fCstatu
#
# /home/mjbales/work/software/root/root_v5.34.36/lib/ROOT.pyc in __getattr2(self, name)
#     484
#     485     # lookup into ROOT (which may cause python-side enum/class/global creation)
# --> 486       attr = _root.LookupRootEntity( name )
#     487
#     488     # the call above will raise AttributeError as necessary; so if we get here,
#
# AttributeError: gMinuit

# %%
c1.Clear()
rid=7371
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
print mean, stdev
histogram.IsA().Destructor( histogram )
range_val=5
histogram = TH1D("phi_hist","phi_hist",100,-range_val,range_val)



drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle(";Normalized Phi;Counts")
histogram.Draw()
lorentizanFunc = TF1("lorentizan", "[0]*[1]*[1]/((x-[2])*(x-[2])+[1]*[1])")
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
print max_bin
print histogram.GetKurtosis()/range_val
lorentizanFunc.SetParNames("Amplitude", "gamma", "x0");
lorentizanFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
# qGaussianFunc.SetParLimits(2,1.0001,3)
lorentizanFunc.SetParameters(max_bin, 3,0)
lorentizanFunc.Print()
histogram.Fit("lorentizan","M")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
# print lorentizanFunc.GetChisquare() / lorentizanFunc.GetNDF()
# qGaussianFunc.Draw("same")
gaus = TF1("gaus","400*TMath::Gaus(x,0,1)",-range_val,range_val)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
# histwnoise.IsA().Destructor( histwnoise )
# histwnoise=srkanalysis.make_phi_hist_with_noise(rid, par, srkmisc.get_hist_dim(histogram), 2*stdev,True)
# histwnoise.SetLineColor(ROOT.kCyan)
# histwnoise.Draw("same")
c1.SetLogy()
c1
# Out:
# 4845.7883801 3.89112902246e-06
# 6883.0
# 0.928581549171
# OK
# <ROOT.TCanvas object ("Canvas") at 0x4fb6ff0>

# %%
c1.Clear()
rid=7371
par=True
par_str='Par_' if par else 'Anti_'
mean,stdev,dip_pos,dip_str = srkdata.get_data_for_rids_from_database([rid],par_str+"PhiMean,"+par_str+"PhiStDev,DipolePositionBelowChamber,DipoleFieldStrength")[0]
print mean, stdev
histogram.IsA().Destructor( histogram )
range_val=5
histogram = TH1D("phi_hist","phi_hist",100,-range_val,range_val)



drawString="(phi-"+str(mean)+")/"+str(stdev)+" >> phi_hist"
c1=srkgraphics.make_root_plot_from_results_file(rid,par,drawString)
histogram.SetTitle(";Normalized Phi;Counts")
histogram.Draw()
#voigtFunc = TF1("voigt", "[0]*[1]*[1]/((Gaus(x,0,[3])-[2])*(x-[2])+[1]*[1])")
voigtFunc = TF1("voigt", "[0]*TMath::Voigt(x-[2],[3],[1])")
max_bin=histogram.GetBinContent(histogram.GetMaximumBin())
print max_bin
print histogram.GetKurtosis()/range_val
voigtFunc.SetParNames("Amplitude", "gamma", "x0","sigma");
voigtFunc.SetParLimits(0,0.5*max_bin,1.5*max_bin)
voigtFunc.SetParLimits(1,0,10)
voigtFunc.SetParLimits(2,-1,1)
voigtFunc.SetParLimits(3,0,1)
# voigtFunc.SetParLimits(2,1.0001,3)
voigtFunc.SetParameters(7.97e3, -3.89e-1,-2.786e-2,1)
voigtFunc.Print()
histogram.Fit("voigt","M")
if ROOT.gMinuit.fCstatu == "CONVERGED ":
    print "YAY!!!"
print ROOT.gMinuit.fCstatu
# print voigtFunc.GetChisquare() / voigtFunc.GetNDF()
# qGaussianFunc.Draw("same")
gaus = TF1("gaus","400*TMath::Gaus(x,0,1)",-range_val,range_val)
gaus.SetLineColor(ROOT.kGreen)
gaus.Draw("same")
# histwnoise.IsA().Destructor( histwnoise )
# histwnoise=srkanalysis.make_phi_hist_with_noise(rid, par, srkmisc.get_hist_dim(histogram), 2*stdev,True)
# histwnoise.SetLineColor(ROOT.kCyan)
# histwnoise.Draw("same")
c1.SetLogy()
c1
# Out:
# 4845.7883801 3.89112902246e-06
# 6883.0
# 0.928581549171
# OK
# <ROOT.TCanvas object ("Canvas") at 0x4fb6ff0>
