# %%
# %matplotlib inline
import srkdata
import matplotlib.pyplot as plt
from matplotlib.legend_handler import HandlerLine2D
from pylab import rcParams
rcParams['figure.figsize'] = 10, 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d787fe46e4d7> in <module>()
#       5 from pylab import rcParams
#       6 rcParams['figure.figsize'] = 10, 5
# ----> 7 plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, num_plots)])
#
# NameError: name 'np' is not defined

# %%
legend_titles=['20 mm distance E=0','10 mm distance,E=0','7 mm distance,E=0','5 mm distance, E=0','1 mm distance, E=0','0.1 mm distance, E=0','1 mm distance,E=1e6 V/m']
lines=[range(321,333),range(335,343),range(349,355),range(217,231),range(247,261),range(231,247),range(263,279)]

# %%
x,y=srkdata.get_plot_data_from_database(lines, "DipoleFieldStrength", "Par_PhiKurtosis")
for i in range(len(lines)):
    a,b=zip(*sorted(zip(x[i],y[i]), key=lambda x: x[0]))
    plt.loglog(a,b,marker='o',label = legend_titles[i])
plt.xlabel('Dipole Field Strength')
plt.ylabel('Kurtosis')
plt.title('Kurtosis')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
x,y=srkdata.get_plot_data_from_database(lines, "DipoleFieldStrength", "Par_PhiPercentileWidth")
for i in range(len(lines)):
    a,b=zip(*sorted(zip(x[i],y[i]), key=lambda x: x[0]))
    plt.loglog(a,b,marker='o',label = legend_titles[i])
plt.xlabel('Dipole Field Strength')
plt.ylabel('69 Percentile Width')
plt.title('Percentile Width')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
x,y=srkdata.get_plot_data_from_database(lines, "DipoleFieldStrength", "Par_PhiStDev")
for i in range(len(lines)):
    a,b=zip(*sorted(zip(x[i],y[i]), key=lambda x: x[0]))
    plt.loglog(a,b,marker='o',label = legend_titles[i])
plt.xlabel('Dipole Field Strength')
plt.ylabel('Standard Deviation')
plt.title('Percentile Width')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
legend_titles=['5 mm distance, E=0','1 mm distance, E=0','0.1 mm distance, E=0','1 mm distance,E=1e6 V/m']
lines=[range(217,231),range(247,261),range(231,247),range(263,279)]
x,y=srkdata.get_plot_data_from_database(lines, "DipoleFieldStrength", "DeltaOmega")
for i in range(len(lines)):
    a,b=zip(*sorted(zip(x[i],y[i]), key=lambda x: x[0]))
    plt.loglog(a,b,marker='o',label = legend_titles[i])
plt.xlabel('Dipole Field Strength')
plt.ylabel(r'$\Delta\omega$')
plt.title('Frequency Shift')
plt.grid(True)
plt.legend(loc='best')
plt.show()
